# %% [markdown]
# #Linear Programing In Python : Deciding Where to Go on Vacation
#
# This iPython Notebook is an Example of Constructing a Linear Program in Python with PULP module.
#
# ----------
# **Problem Formulation:**
# You want to go on vacation, but you have only limited number of days. On top of it, we also want keep the cost at minimum.
# And the internet offers plenty of options how to decide, so which packages/mix of packages should we select?
#
# ----------
# > - Objective: Minimize Cost of Vacation while selecting Optimal Vacation Package
# > - LP Form: Minimization
# > - Decision Variables: Binary Variables whether to purchase the package or not.
# > - Constrains: Limited Number of Vacation

# %%
from pulp import *
import numpy as np
import pandas as pd
import re 
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# **Understanding the Dataset**
# >The dataset contains:
# > - Final Destination
# > - Duration of the trip
# > - Total Cost of the trip
# > - Short Description of the adventure

# %%
data = pd.read_excel('clymb_adventures.xlsx')
data[:5]
# Out:
#   destination  duration  cost  \
# 0        Baja         7   899
# 1       Nepal        11   899
# 2       Spain         8   568
# 3    Yosemite         5   750
# 4        Utah         6  1356
#
#                                          description
# 0  Hike Bike and Sea Kayak and more on a Remote P...
# 1  Explore the land and culture of the Himalayas....
# 2  Sport climb & deep water solo in Mallorca. Dis...
# 3  Guided hiking through stunning high country. E...
# 4  Hike. Canyoneer. Rock Climb. and more!. Experi...

# %%
fig, axs = plt.subplots(1,2)
my_plot = data[['destination', 'cost']].plot(kind='bar', title="Destination by Cost", ax=axs[0])
my_plot = data[['destination', 'duration']].plot(kind='bar', title="Destination by Duration", ax=axs[1])

# %% [markdown]
# **Setting Up LP Problem:**
#
# > Define The LP Object
#
# > The *prob* variable is created to contain the formulation, and the usual parameters are passed into LpProblem.

# %%
# create the LP object, set up as a minimization problem --> since we want to minimize the costs 
prob = pulp.LpProblem('GoingOnVacation', pulp.LpMinimize)

# %% [markdown]
# > Create Decision Variables:

# %%
for rownum, row in data.iterrows():
        variable = str('x' + str(rownum))
        #print(variable)
        print(rownum)
        print('/')
        print(row)
        print('..//..')
# Out:
# 0
# /
# destination                                                 Baja
# duration                                                       7
# cost                                                         899
# description    Hike Bike and Sea Kayak and more on a Remote P...
# decision                                                       0
# Name: 0, dtype: object
# ..//..
# 1
# /
# destination                                                Nepal
# duration                                                      11
# cost                                                         899
# description    Explore the land and culture of the Himalayas....
# decision                                                       0
# Name: 1, dtype: object
# ..//..
# 2
# /
# destination                                                Spain
# duration                                                       8
# cost                                                         568
# description    Sport climb & deep water solo in Mallorca. Dis...
# decision                                                       0
# Name: 2, dtype: object
# ..//..
# 3
# /
# destination                                             Yosemite
# duration                                                       5
# cost                                                         750
# description    Guided hiking through stunning high country. E...
# decision                                                       0
# Name: 3, dtype: object
# ..//..
# 4
# /
# destination                                                 Utah
# duration                                                       6
# cost                                                        1356
# description    Hike. Canyoneer. Rock Climb. and more!. Experi...
# decision                                                       0
# Name: 4, dtype: object
# ..//..
# 5
# /
# destination                                                 Utah
# duration                                                       4
# cost                                                         680
# description    Ride mountain bike through Canyonlands. Follow...
# decision                                                       0
# Name: 5, dtype: object
# ..//..
# 6
# /
# destination                                     San Juan Islands
# duration                                                       4
# cost                                                         559
# description    Kayak in search of orca whales. Kayak amongst ...
# decision                                                       0
# Name: 6, dtype: object
# ..//..
# 7
# /
# destination                                               Oregon
# duration                                                       6
# cost                                                         899
# description    Circumnavigate Crater Lake. Experience the pri...
# decision                                                       0
# Name: 7, dtype: object
# ..//..
# 8
# /
# destination                                               Hawaii
# duration                                                      10
# cost                                                        1799
# description    Surf. Hike. Zipline. Swim. Snorkel. And more!....
# decision                                                       0
# Name: 8, dtype: object
# ..//..
# 9
# /
# destination                                               Alaska
# duration                                                       7
# cost                                                        1625
# description    Wilderness Packrafting. Packrafting is quickly...
# decision                                                       0
# Name: 9, dtype: object
# ..//..
# 10
# /
# destination                                          New England
# duration                                                       2
# cost                                                         399
# description    Summit Mt. Washington. Summit the highest moun...
# decision                                                       0
# Name: 10, dtype: object
# ..//..
# 11
# /
# destination                                          New England
# duration                                                       2
# cost                                                         385
# description    Learn to ice climb. Trip for Two!. Grab a frie...
# decision                                                       0
# Name: 11, dtype: object
# ..//..
# 12
# /
# destination                                             Colorado
# duration                                                       3
# cost                                                         439
# description    AIARE Level I Alpine Instructional Course. Ear...
# decision                                                       0
# Name: 12, dtype: object
# ..//..
# 13
# /
# destination                                             Colorado
# duration                                                       2
# cost                                                         339
# description    Learn to ice climb. Learn the basics of ice cl...
# decision                                                       0
# Name: 13, dtype: object
# ..//..
# 14
# /
# destination                                  Washington Cascades
# duration                                                       3
# cost                                                         399
# description    Summit Mt. Adams. Do something that makes you ...
# decision                                                       0
# Name: 14, dtype: object
# ..//..
# 15
# /
# destination                                                Maine
# duration                                                       4
# cost                                                         265
# description    Ride endless singletrack. Escape to Western Ma...
# decision                                                       1
# Name: 15, dtype: object
# ..//..
# 16
# /
# destination                                                 Peru
# duration                                                       7
# cost                                                         849
# description    Trek the Inca Trail to Machu Picchu. Trek the ...
# decision                                                       0
# Name: 16, dtype: object
# ..//..
# 17
# /
# destination                                                 Peru
# duration                                                       8
# cost                                                        1799
# description    Trek the Inca Trail to Machu Picchu. Air inclu...
# decision                                                       0
# Name: 17, dtype: object
# ..//..
# 18
# /
# destination                                              Vietnam
# duration                                                      10
# cost                                                        1799
# description    Sport climb and deep water solo in Ha Long Bay...
# decision                                                       0
# Name: 18, dtype: object
# ..//..
# 19
# /
# destination                                            Patagonia
# duration                                                       7
# cost                                                        1499
# description    Backcountry ski tour in the Andes. Embark on a...
# decision                                                       0
# Name: 19, dtype: object
# ..//..
# 20
# /
# destination                                   Peru and Galapagos
# duration                                                      13
# cost                                                        3175
# description    Trek the Inca Trail to Machu Picchu and Explor...
# decision                                                       0
# Name: 20, dtype: object
# ..//..
# 21
# /
# destination                                             Colorado
# duration                                                       3
# cost                                                         599
# description    Hut to Hut backcountry skiing in the San Juan ...
# decision                                                       0
# Name: 21, dtype: object
# ..//..
# 22
# /
# destination                                          New England
# duration                                                       5
# cost                                                        1450
# description    Learn to mountaineer & summit two peaks. Learn...
# decision                                                       0
# Name: 22, dtype: object
# ..//..
# 23
# /
# destination                                             Colorado
# duration                                                       2
# cost                                                         399
# description    Lern to Ice Climb in the San Juan Mountains. A...
# decision                                                       0
# Name: 23, dtype: object
# ..//..
# 24
# /
# destination                                             Colorado
# duration                                                       5
# cost                                                        1199
# description    Incrtuctional Winter Mountaineering Course. Sn...
# decision                                                       0
# Name: 24, dtype: object
# ..//..
# 25
# /
# destination                                              Ecuador
# duration                                                       9
# cost                                                        2799
# description    Hike kayak MTB and stay in boutique hotels. Hi...
# decision                                                       0
# Name: 25, dtype: object
# ..//..
# 26
# /
# destination                        Vietnam Thailand and Cambodia
# duration                                                      14
# cost                                                        2675
# description    Cycle from Saigon to Bangkok. Cycle 400 miles ...
# decision                                                       0
# Name: 26, dtype: object
# ..//..
# 27
# /
# destination                                            Patagonia
# duration                                                       8
# cost                                                        1699
# description    Explore the Southern Ice Field. Travel to a re...
# decision                                                       0
# Name: 27, dtype: object
# ..//..
# 28
# /
# destination                                   Dominican Republic
# duration                                                       4
# cost                                                         599
# description    Learn to kite surf in the Caribbean. The Domin...
# decision                                                       0
# Name: 28, dtype: object
# ..//..
# 29
# /
# destination                                           Costa Rica
# duration                                                       6
# cost                                                        1798
# description    Rainforest sanctuary and retreat. Trip for 2!....
# decision                                                       0
# Name: 29, dtype: object
# ..//..
# 30
# /
# destination                                                Crete
# duration                                                       8
# cost                                                        1799
# description    Kayak stunning Mediterranean coastline. Kayak ...
# decision                                                       0
# Name: 30, dtype: object
# ..//..
# 31
# /
# destination                                                Nepal
# duration                                                      11
# cost                                                        1199
# description    Mountain bike & go on a Jeep safari. This biki...
# decision                                                       0
# Name: 31, dtype: object
# ..//..
# 32
# /
# destination                                           Costa Rica
# duration                                                       8
# cost                                                         999
# description    A Yoga Retreat in Caribbean Paradise. Center y...
# decision                                                       0
# Name: 32, dtype: object
# ..//..
# 33
# /
# destination                                              Ecuador
# duration                                                       8
# cost                                                        1375
# description    Mountain bike and waterfall rappel. Join the b...
# decision                                                       0
# Name: 33, dtype: object
# ..//..
# 34
# /
# destination                                                Nepal
# duration                                                      13
# cost                                                        1199
# description    Rebuild villages and trek the Annapurna region...
# decision                                                       0
# Name: 34, dtype: object
# ..//..
# 35
# /
# destination                                               Oregon
# duration                                                       4
# cost                                                         299
# description    Mountain bike from hut-to-hut on the Mt Hood L...
# decision                                                       1
# Name: 35, dtype: object
# ..//..
# 36
# /
# destination                                               Oregon
# duration                                                       6
# cost                                                        2898
# description    Crater Lake to Bend Cycling Tour. Skirt the ri...
# decision                                                       0
# Name: 36, dtype: object
# ..//..
# 37
# /
# destination                                               Oregon
# duration                                                       3
# cost                                                         499
# description    Raft the John Day River. With very few rapids ...
# decision                                                       0
# Name: 37, dtype: object
# ..//..
# 38
# /
# destination                                               Oregon
# duration                                                       5
# cost                                                        1499
# description    Horsepack-assisted hiking in the Wallowas for ...
# decision                                                       0
# Name: 38, dtype: object
# ..//..
# 39
# /
# destination                                               Oregon
# duration                                                       4
# cost                                                         450
# description    Climb Smith Rock. Journey to the mecca of mode...
# decision                                                       0
# Name: 39, dtype: object
# ..//..
# 40
# /
# destination                                               Oregon
# duration                                                       2
# cost                                                         198
# description    Learn to windsurf in Hood River. Trip for 2!. ...
# decision                                                       1
# Name: 40, dtype: object
# ..//..
# 41
# /
# destination                                               Oregon
# duration                                                       2
# cost                                                         375
# description    Learn to surf & sip on fine whiskey. Need a te...
# decision                                                       0
# Name: 41, dtype: object
# ..//..

# %%
decision_variables = []
for rownum, row in data.iterrows():
	variable = str('x' + str(rownum))
	variable = pulp.LpVariable(str(variable), lowBound = 0, upBound = 1, cat= 'Integer') #make variables binary
	decision_variables.append(variable)

print ("Total number of decision_variables: " + str(len(decision_variables)))
print ("Array with Decision Variables:" + str(decision_variables))
# Out:
# Total number of decision_variables: 42
# Array with Decision Variables:[x0, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25, x26, x27, x28, x29, x30, x31, x32, x33, x34, x35, x36, x37, x38, x39, x40, x41]

# %% [markdown]
# > Define Objective Function: (*Minimixing the Cost of The Trip*)
#
# > The variable prob now begins collecting problem data with the += operator. The objective function is logically entered first, with an important comma , at the end of the statement and a short string explaining what this objective function is:> Define Objective Function: (*Minimixing the Cost of The Trip*)
#
# > The variable prob now begins collecting problem data with the += operator. The objective function is logically entered first, with an important comma , at the end of the statement and a short string explaining what this objective function is:

# %%
for i, schedule in enumerate(decision_variables):
    print(i)
    print(schedule)
# Out:
# 0
# x0
# 1
# x1
# 2
# x2
# 3
# x3
# 4
# x4
# 5
# x5
# 6
# x6
# 7
# x7
# 8
# x8
# 9
# x9
# 10
# x10
# 11
# x11
# 12
# x12
# 13
# x13
# 14
# x14
# 15
# x15
# 16
# x16
# 17
# x17
# 18
# x18
# 19
# x19
# 20
# x20
# 21
# x21
# 22
# x22
# 23
# x23
# 24
# x24
# 25
# x25
# 26
# x26
# 27
# x27
# 28
# x28
# 29
# x29
# 30
# x30
# 31
# x31
# 32
# x32
# 33
# x33
# 34
# x34
# 35
# x35
# 36
# x36
# 37
# x37
# 38
# x38
# 39
# x39
# 40
# x40
# 41
# x41

# %%
total_cost = ""
for rownum, row in data.iterrows():
        for i, schedule in enumerate(decision_variables):
            if rownum == i:
                formula = row['cost']*schedule
                #print(formula)
                total_cost += formula
                print(total_cost)

prob += total_cost
print ("Optimization function: " + str(total_cost))
# Out:
# 899*x0
# 899*x0 + 899*x1
# 899*x0 + 899*x1 + 568*x2
# 899*x0 + 899*x1 + 568*x2 + 750*x3
# 899*x0 + 899*x1 + 568*x2 + 750*x3 + 1356*x4
# 899*x0 + 899*x1 + 568*x2 + 750*x3 + 1356*x4 + 680*x5
# 899*x0 + 899*x1 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6
# 899*x0 + 899*x1 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7
# 899*x0 + 899*x1 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8
# 899*x0 + 899*x1 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 499*x37 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 499*x37 + 1499*x38 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 499*x37 + 1499*x38 + 450*x39 + 1356*x4 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 499*x37 + 1499*x38 + 450*x39 + 1356*x4 + 198*x40 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 499*x37 + 1499*x38 + 450*x39 + 1356*x4 + 198*x40 + 375*x41 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# Optimization function: 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 499*x37 + 1499*x38 + 450*x39 + 1356*x4 + 198*x40 + 375*x41 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9
# C:\Users\shakib\Anaconda3\lib\site-packages\pulp\pulp.py:1349: UserWarning: Overwriting previously set objective.
#   warnings.warn("Overwriting previously set objective.")

# %% [markdown]
# > Define Constrains: (*Selected Packages should not exceed total vacation days available*)

# %%
aval_vacation_days = 10
total_vacation_days = ""
for rownum, row in data.iterrows():
	for i, schedule in enumerate(decision_variables):
		if rownum == i:
			formula = row['duration']*schedule
			total_vacation_days += formula

prob += (total_vacation_days == aval_vacation_days)

# %% [markdown]
# >The Final Format

# %%
print(prob)
prob.writeLP("GoingOnVacation.lp" )
# Out:
# GoingOnVacation:
# MINIMIZE
# 899*x0 + 899*x1 + 399*x10 + 385*x11 + 439*x12 + 339*x13 + 399*x14 + 265*x15 + 849*x16 + 1799*x17 + 1799*x18 + 1499*x19 + 568*x2 + 3175*x20 + 599*x21 + 1450*x22 + 399*x23 + 1199*x24 + 2799*x25 + 2675*x26 + 1699*x27 + 599*x28 + 1798*x29 + 750*x3 + 1799*x30 + 1199*x31 + 999*x32 + 1375*x33 + 1199*x34 + 299*x35 + 2898*x36 + 499*x37 + 1499*x38 + 450*x39 + 1356*x4 + 198*x40 + 375*x41 + 680*x5 + 559*x6 + 899*x7 + 1799*x8 + 1625*x9 + 0
# SUBJECT TO
# _C1: 7 x0 + 11 x1 + 2 x10 + 2 x11 + 3 x12 + 2 x13 + 3 x14 + 4 x15 + 7 x16
#  + 8 x17 + 10 x18 + 7 x19 + 8 x2 + 13 x20 + 3 x21 + 5 x22 + 2 x23 + 5 x24
#  + 9 x25 + 14 x26 + 8 x27 + 4 x28 + 6 x29 + 5 x3 + 8 x30 + 11 x31 + 8 x32
#  + 8 x33 + 13 x34 + 4 x35 + 6 x36 + 3 x37 + 5 x38 + 4 x39 + 6 x4 + 2 x40
#  + 2 x41 + 4 x5 + 4 x6 + 6 x7 + 10 x8 + 7 x9 = 10
#
# VARIABLES
# 0 <= x0 <= 1 Integer
# 0 <= x1 <= 1 Integer
# 0 <= x10 <= 1 Integer
# 0 <= x11 <= 1 Integer
# 0 <= x12 <= 1 Integer
# 0 <= x13 <= 1 Integer
# 0 <= x14 <= 1 Integer
# 0 <= x15 <= 1 Integer
# 0 <= x16 <= 1 Integer
# 0 <= x17 <= 1 Integer
# 0 <= x18 <= 1 Integer
# 0 <= x19 <= 1 Integer
# 0 <= x2 <= 1 Integer
# 0 <= x20 <= 1 Integer
# 0 <= x21 <= 1 Integer
# 0 <= x22 <= 1 Integer
# 0 <= x23 <= 1 Integer
# 0 <= x24 <= 1 Integer
# 0 <= x25 <= 1 Integer
# 0 <= x26 <= 1 Integer
# 0 <= x27 <= 1 Integer
# 0 <= x28 <= 1 Integer
# 0 <= x29 <= 1 Integer
# 0 <= x3 <= 1 Integer
# 0 <= x30 <= 1 Integer
# 0 <= x31 <= 1 Integer
# 0 <= x32 <= 1 Integer
# 0 <= x33 <= 1 Integer
# 0 <= x34 <= 1 Integer
# 0 <= x35 <= 1 Integer
# 0 <= x36 <= 1 Integer
# 0 <= x37 <= 1 Integer
# 0 <= x38 <= 1 Integer
# 0 <= x39 <= 1 Integer
# 0 <= x4 <= 1 Integer
# 0 <= x40 <= 1 Integer
# 0 <= x41 <= 1 Integer
# 0 <= x5 <= 1 Integer
# 0 <= x6 <= 1 Integer
# 0 <= x7 <= 1 Integer
# 0 <= x8 <= 1 Integer
# 0 <= x9 <= 1 Integer

# %% [markdown]
# > The Actual Optimization:

# %%
optimization_result = prob.solve()

assert optimization_result == pulp.LpStatusOptimal
print("Status:", LpStatus[prob.status])
print("Optimal Solution to the problem: ", value(prob.objective))
print ("Individual decision_variables: ")
for v in prob.variables():
	print(v.name, "=", v.varValue)
# Out:
# Status: Optimal
# Optimal Solution to the problem:  762.0
# Individual decision_variables:
# x0 = 0.0
# x1 = 0.0
# x10 = 0.0
# x11 = 0.0
# x12 = 0.0
# x13 = 0.0
# x14 = 0.0
# x15 = 1.0
# x16 = 0.0
# x17 = 0.0
# x18 = 0.0
# x19 = 0.0
# x2 = 0.0
# x20 = 0.0
# x21 = 0.0
# x22 = 0.0
# x23 = 0.0
# x24 = 0.0
# x25 = 0.0
# x26 = 0.0
# x27 = 0.0
# x28 = 0.0
# x29 = 0.0
# x3 = 0.0
# x30 = 0.0
# x31 = 0.0
# x32 = 0.0
# x33 = 0.0
# x34 = 0.0
# x35 = 1.0
# x36 = 0.0
# x37 = 0.0
# x38 = 0.0
# x39 = 0.0
# x4 = 0.0
# x40 = 1.0
# x41 = 0.0
# x5 = 0.0
# x6 = 0.0
# x7 = 0.0
# x8 = 0.0
# x9 = 0.0

# %% [markdown]
# > The results are stored
# > If you don't pass the names to the variables and want to append the decision variables back in your desired file format, you want to loop through variable name object.
#
# > Depending on your initial data format you might want to parse the results differently. Since in this example we have used pandas dataframe, we will use the number of the variable as index to append the results back to initial dataset

# %%
variable_name = []
variable_value = []

for v in prob.variables():
	variable_name.append(v.name)
	variable_value.append(v.varValue)

df = pd.DataFrame({'variable': variable_name, 'value': variable_value})
for rownum, row in df.iterrows():
	value = re.findall(r'(\d+)', row['variable'])
	df.loc[rownum, 'variable'] = int(value[0])

df = df.sort_index(by='variable')

#append results
for rownum, row in data.iterrows():
	for results_rownum, results_row in df.iterrows():
		if rownum == results_row['variable']:
			data.loc[rownum, 'decision'] = results_row['value']
            
data[:5]
# Out:
# C:\Users\shakib\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)
#   del sys.path[0]
#   destination  duration  cost  \
# 0        Baja         7   899
# 1       Nepal        11   899
# 2       Spain         8   568
# 3    Yosemite         5   750
# 4        Utah         6  1356
#
#                                          description  decision
# 0  Hike Bike and Sea Kayak and more on a Remote P...       0.0
# 1  Explore the land and culture of the Himalayas....       0.0
# 2  Sport climb & deep water solo in Mallorca. Dis...       0.0
# 3  Guided hiking through stunning high country. E...       0.0
# 4  Hike. Canyoneer. Rock Climb. and more!. Experi...       0.0

# %% [markdown]
# > The Final Decisions and Results of the Optimization in the "User Friendly Way":

# %%
data[data['decision'] == 1]
# Out:
#    destination  duration  cost  \
# 15       Maine         4   265
# 35      Oregon         4   299
# 40      Oregon         2   198
#
#                                           description  decision
# 15  Ride endless singletrack. Escape to Western Ma...       1.0
# 35  Mountain bike from hut-to-hut on the Mt Hood L...       1.0
# 40  Learn to windsurf in Hood River. Trip for 2!. ...       1.0

# %%
data[data['decision'] == 1]['cost'].sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-e0c72df855dc> in <module>()
# ----> 1 data[data['decision'] == 1]['cost'].sum(axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10929                                       skipna=skipna, min_count=min_count)
#   10930         return self._reduce(f, name, axis=axis, skipna=skipna,
# > 10931                             numeric_only=numeric_only, min_count=min_count)
#   10932
#   10933     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3609
#    3610         if axis is not None:
# -> 3611             self._get_axis_number(axis)
#    3612
#    3613         if isinstance(delegate, Categorical):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     359                 pass
#     360         raise ValueError('No axis named {0} for object type {1}'
# --> 361                          .format(axis, type(cls)))
#     362
#     363     @classmethod
#
# ValueError: No axis named 1 for object type <class 'type'>
