# %%
# Import PuLP modeler functions
from pulp import *
import pandas as pd

# %%
max_tables = 5
max_table_size = 4
guests = 'A B C D E F G I J K L M N O P Q R'.split()

# %%
guests
# Out:
# ['A',
#  'B',
#  'C',
#  'D',
#  'E',
#  'F',
#  'G',
#  'I',
#  'J',
#  'K',
#  'L',
#  'M',
#  'N',
#  'O',
#  'P',
#  'Q',
#  'R']

# %%
def happiness(table):
    """
    Find the happiness of the table
    - by calculating the maximum distance between the letters
    abs for absolate value
    ord for unicode value
    """
    return abs(ord(table[0]) - ord(table[-1]))

# %%
#create list of all possible tables
possible_tables = [tuple(c) for c in pulp.allcombinations(guests, 
                                        max_table_size)]

# %%
len(possible_tables)
# Out:
# 3213

# %%
#create a binary variable to state that a table setting is used
x = pulp.LpVariable.dicts('table', possible_tables, 
                            lowBound = 0,
                            upBound = 1,
                            cat = pulp.LpInteger)

# %%
x
# Out:
# {('A',): table_('A',),
#  ('B',): table_('B',),
#  ('C',): table_('C',),
#  ('D',): table_('D',),
#  ('E',): table_('E',),
#  ('F',): table_('F',),
#  ('G',): table_('G',),
#  ('I',): table_('I',),
#  ('J',): table_('J',),
#  ('K',): table_('K',),
#  ('L',): table_('L',),
#  ('M',): table_('M',),
#  ('N',): table_('N',),
#  ('O',): table_('O',),
#  ('P',): table_('P',),
#  ('Q',): table_('Q',),
#  ('R',): table_('R',),
#  ('A', 'B'): table_('A',_'B'),
#  ('A', 'C'): table_('A',_'C'),
#  ('A', 'D'): table_('A',_'D'),
#  ('A', 'E'): table_('A',_'E'),
#  ('A', 'F'): table_('A',_'F'),
#  ('A', 'G'): table_('A',_'G'),
#  ('A', 'I'): table_('A',_'I'),
#  ('A', 'J'): table_('A',_'J'),
#  ('A', 'K'): table_('A',_'K'),
#  ('A', 'L'): table_('A',_'L'),
#  ('A', 'M'): table_('A',_'M'),
#  ('A', 'N'): table_('A',_'N'),
#  ('A', 'O'): table_('A',_'O'),
#  ('A', 'P'): table_('A',_'P'),
#  ('A', 'Q'): table_('A',_'Q'),
#  ('A', 'R'): table_('A',_'R'),
#  ('B', 'C'): table_('B',_'C'),
#  ('B', 'D'): table_('B',_'D'),
#  ('B', 'E'): table_('B',_'E'),
#  ('B', 'F'): table_('B',_'F'),
#  ('B', 'G'): table_('B',_'G'),
#  ('B', 'I'): table_('B',_'I'),
#  ('B', 'J'): table_('B',_'J'),
#  ('B', 'K'): table_('B',_'K'),
#  ('B', 'L'): table_('B',_'L'),
#  ('B', 'M'): table_('B',_'M'),
#  ('B', 'N'): table_('B',_'N'),
#  ('B', 'O'): table_('B',_'O'),
#  ('B', 'P'): table_('B',_'P'),
#  ('B', 'Q'): table_('B',_'Q'),
#  ('B', 'R'): table_('B',_'R'),
#  ('C', 'D'): table_('C',_'D'),
#  ('C', 'E'): table_('C',_'E'),
#  ('C', 'F'): table_('C',_'F'),
#  ('C', 'G'): table_('C',_'G'),
#  ('C', 'I'): table_('C',_'I'),
#  ('C', 'J'): table_('C',_'J'),
#  ('C', 'K'): table_('C',_'K'),
#  ('C', 'L'): table_('C',_'L'),
#  ('C', 'M'): table_('C',_'M'),
#  ('C', 'N'): table_('C',_'N'),
#  ('C', 'O'): table_('C',_'O'),
#  ('C', 'P'): table_('C',_'P'),
#  ('C', 'Q'): table_('C',_'Q'),
#  ('C', 'R'): table_('C',_'R'),
#  ('D', 'E'): table_('D',_'E'),
#  ('D', 'F'): table_('D',_'F'),
#  ('D', 'G'): table_('D',_'G'),
#  ('D', 'I'): table_('D',_'I'),
#  ('D', 'J'): table_('D',_'J'),
#  ('D', 'K'): table_('D',_'K'),
#  ('D', 'L'): table_('D',_'L'),
#  ('D', 'M'): table_('D',_'M'),
#  ('D', 'N'): table_('D',_'N'),
#  ('D', 'O'): table_('D',_'O'),
#  ('D', 'P'): table_('D',_'P'),
#  ('D', 'Q'): table_('D',_'Q'),
#  ('D', 'R'): table_('D',_'R'),
#  ('E', 'F'): table_('E',_'F'),
#  ('E', 'G'): table_('E',_'G'),
#  ('E', 'I'): table_('E',_'I'),
#  ('E', 'J'): table_('E',_'J'),
#  ('E', 'K'): table_('E',_'K'),
#  ('E', 'L'): table_('E',_'L'),
#  ('E', 'M'): table_('E',_'M'),
#  ('E', 'N'): table_('E',_'N'),
#  ('E', 'O'): table_('E',_'O'),
#  ('E', 'P'): table_('E',_'P'),
#  ('E', 'Q'): table_('E',_'Q'),
#  ('E', 'R'): table_('E',_'R'),
#  ('F', 'G'): table_('F',_'G'),
#  ('F', 'I'): table_('F',_'I'),
#  ('F', 'J'): table_('F',_'J'),
#  ('F', 'K'): table_('F',_'K'),
#  ('F', 'L'): table_('F',_'L'),
#  ('F', 'M'): table_('F',_'M'),
#  ('F', 'N'): table_('F',_'N'),
#  ('F', 'O'): table_('F',_'O'),
#  ('F', 'P'): table_('F',_'P'),
#  ('F', 'Q'): table_('F',_'Q'),
#  ('F', 'R'): table_('F',_'R'),
#  ('G', 'I'): table_('G',_'I'),
#  ('G', 'J'): table_('G',_'J'),
#  ('G', 'K'): table_('G',_'K'),
#  ('G', 'L'): table_('G',_'L'),
#  ('G', 'M'): table_('G',_'M'),
#  ('G', 'N'): table_('G',_'N'),
#  ('G', 'O'): table_('G',_'O'),
#  ('G', 'P'): table_('G',_'P'),
#  ('G', 'Q'): table_('G',_'Q'),
#  ('G', 'R'): table_('G',_'R'),
#  ('I', 'J'): table_('I',_'J'),
#  ('I', 'K'): table_('I',_'K'),
#  ('I', 'L'): table_('I',_'L'),
#  ('I', 'M'): table_('I',_'M'),
#  ('I', 'N'): table_('I',_'N'),
#  ('I', 'O'): table_('I',_'O'),
#  ('I', 'P'): table_('I',_'P'),
#  ('I', 'Q'): table_('I',_'Q'),
#  ('I', 'R'): table_('I',_'R'),
#  ('J', 'K'): table_('J',_'K'),
#  ('J', 'L'): table_('J',_'L'),
#  ('J', 'M'): table_('J',_'M'),
#  ('J', 'N'): table_('J',_'N'),
#  ('J', 'O'): table_('J',_'O'),
#  ('J', 'P'): table_('J',_'P'),
#  ('J', 'Q'): table_('J',_'Q'),
#  ('J', 'R'): table_('J',_'R'),
#  ('K', 'L'): table_('K',_'L'),
#  ('K', 'M'): table_('K',_'M'),
#  ('K', 'N'): table_('K',_'N'),
#  ('K', 'O'): table_('K',_'O'),
#  ('K', 'P'): table_('K',_'P'),
#  ('K', 'Q'): table_('K',_'Q'),
#  ('K', 'R'): table_('K',_'R'),
#  ('L', 'M'): table_('L',_'M'),
#  ('L', 'N'): table_('L',_'N'),
#  ('L', 'O'): table_('L',_'O'),
#  ('L', 'P'): table_('L',_'P'),
#  ('L', 'Q'): table_('L',_'Q'),
#  ('L', 'R'): table_('L',_'R'),
#  ('M', 'N'): table_('M',_'N'),
#  ('M', 'O'): table_('M',_'O'),
#  ('M', 'P'): table_('M',_'P'),
#  ('M', 'Q'): table_('M',_'Q'),
#  ('M', 'R'): table_('M',_'R'),
#  ('N', 'O'): table_('N',_'O'),
#  ('N', 'P'): table_('N',_'P'),
#  ('N', 'Q'): table_('N',_'Q'),
#  ('N', 'R'): table_('N',_'R'),
#  ('O', 'P'): table_('O',_'P'),
#  ('O', 'Q'): table_('O',_'Q'),
#  ('O', 'R'): table_('O',_'R'),
#  ('P', 'Q'): table_('P',_'Q'),
#  ('P', 'R'): table_('P',_'R'),
#  ('Q', 'R'): table_('Q',_'R'),
#  ('A', 'B', 'C'): table_('A',_'B',_'C'),
#  ('A', 'B', 'D'): table_('A',_'B',_'D'),
#  ('A', 'B', 'E'): table_('A',_'B',_'E'),
#  ('A', 'B', 'F'): table_('A',_'B',_'F'),
#  ('A', 'B', 'G'): table_('A',_'B',_'G'),
#  ('A', 'B', 'I'): table_('A',_'B',_'I'),
#  ('A', 'B', 'J'): table_('A',_'B',_'J'),
#  ('A', 'B', 'K'): table_('A',_'B',_'K'),
#  ('A', 'B', 'L'): table_('A',_'B',_'L'),
#  ('A', 'B', 'M'): table_('A',_'B',_'M'),
#  ('A', 'B', 'N'): table_('A',_'B',_'N'),
#  ('A', 'B', 'O'): table_('A',_'B',_'O'),
#  ('A', 'B', 'P'): table_('A',_'B',_'P'),
#  ('A', 'B', 'Q'): table_('A',_'B',_'Q'),
#  ('A', 'B', 'R'): table_('A',_'B',_'R'),
#  ('A', 'C', 'D'): table_('A',_'C',_'D'),
#  ('A', 'C', 'E'): table_('A',_'C',_'E'),
#  ('A', 'C', 'F'): table_('A',_'C',_'F'),
#  ('A', 'C', 'G'): table_('A',_'C',_'G'),
#  ('A', 'C', 'I'): table_('A',_'C',_'I'),
#  ('A', 'C', 'J'): table_('A',_'C',_'J'),
#  ('A', 'C', 'K'): table_('A',_'C',_'K'),
#  ('A', 'C', 'L'): table_('A',_'C',_'L'),
#  ('A', 'C', 'M'): table_('A',_'C',_'M'),
#  ('A', 'C', 'N'): table_('A',_'C',_'N'),
#  ('A', 'C', 'O'): table_('A',_'C',_'O'),
#  ('A', 'C', 'P'): table_('A',_'C',_'P'),
#  ('A', 'C', 'Q'): table_('A',_'C',_'Q'),
#  ('A', 'C', 'R'): table_('A',_'C',_'R'),
#  ('A', 'D', 'E'): table_('A',_'D',_'E'),
#  ('A', 'D', 'F'): table_('A',_'D',_'F'),
#  ('A', 'D', 'G'): table_('A',_'D',_'G'),
#  ('A', 'D', 'I'): table_('A',_'D',_'I'),
#  ('A', 'D', 'J'): table_('A',_'D',_'J'),
#  ('A', 'D', 'K'): table_('A',_'D',_'K'),
#  ('A', 'D', 'L'): table_('A',_'D',_'L'),
#  ('A', 'D', 'M'): table_('A',_'D',_'M'),
#  ('A', 'D', 'N'): table_('A',_'D',_'N'),
#  ('A', 'D', 'O'): table_('A',_'D',_'O'),
#  ('A', 'D', 'P'): table_('A',_'D',_'P'),
#  ('A', 'D', 'Q'): table_('A',_'D',_'Q'),
#  ('A', 'D', 'R'): table_('A',_'D',_'R'),
#  ('A', 'E', 'F'): table_('A',_'E',_'F'),
#  ('A', 'E', 'G'): table_('A',_'E',_'G'),
#  ('A', 'E', 'I'): table_('A',_'E',_'I'),
#  ('A', 'E', 'J'): table_('A',_'E',_'J'),
#  ('A', 'E', 'K'): table_('A',_'E',_'K'),
#  ('A', 'E', 'L'): table_('A',_'E',_'L'),
#  ('A', 'E', 'M'): table_('A',_'E',_'M'),
#  ('A', 'E', 'N'): table_('A',_'E',_'N'),
#  ('A', 'E', 'O'): table_('A',_'E',_'O'),
#  ('A', 'E', 'P'): table_('A',_'E',_'P'),
#  ('A', 'E', 'Q'): table_('A',_'E',_'Q'),
#  ('A', 'E', 'R'): table_('A',_'E',_'R'),
#  ('A', 'F', 'G'): table_('A',_'F',_'G'),
#  ('A', 'F', 'I'): table_('A',_'F',_'I'),
#  ('A', 'F', 'J'): table_('A',_'F',_'J'),
#  ('A', 'F', 'K'): table_('A',_'F',_'K'),
#  ('A', 'F', 'L'): table_('A',_'F',_'L'),
#  ('A', 'F', 'M'): table_('A',_'F',_'M'),
#  ('A', 'F', 'N'): table_('A',_'F',_'N'),
#  ('A', 'F', 'O'): table_('A',_'F',_'O'),
#  ('A', 'F', 'P'): table_('A',_'F',_'P'),
#  ('A', 'F', 'Q'): table_('A',_'F',_'Q'),
#  ('A', 'F', 'R'): table_('A',_'F',_'R'),
#  ('A', 'G', 'I'): table_('A',_'G',_'I'),
#  ('A', 'G', 'J'): table_('A',_'G',_'J'),
#  ('A', 'G', 'K'): table_('A',_'G',_'K'),
#  ('A', 'G', 'L'): table_('A',_'G',_'L'),
#  ('A', 'G', 'M'): table_('A',_'G',_'M'),
#  ('A', 'G', 'N'): table_('A',_'G',_'N'),
#  ('A', 'G', 'O'): table_('A',_'G',_'O'),
#  ('A', 'G', 'P'): table_('A',_'G',_'P'),
#  ('A', 'G', 'Q'): table_('A',_'G',_'Q'),
#  ('A', 'G', 'R'): table_('A',_'G',_'R'),
#  ('A', 'I', 'J'): table_('A',_'I',_'J'),
#  ('A', 'I', 'K'): table_('A',_'I',_'K'),
#  ('A', 'I', 'L'): table_('A',_'I',_'L'),
#  ('A', 'I', 'M'): table_('A',_'I',_'M'),
#  ('A', 'I', 'N'): table_('A',_'I',_'N'),
#  ('A', 'I', 'O'): table_('A',_'I',_'O'),
#  ('A', 'I', 'P'): table_('A',_'I',_'P'),
#  ('A', 'I', 'Q'): table_('A',_'I',_'Q'),
#  ('A', 'I', 'R'): table_('A',_'I',_'R'),
#  ('A', 'J', 'K'): table_('A',_'J',_'K'),
#  ('A', 'J', 'L'): table_('A',_'J',_'L'),
#  ('A', 'J', 'M'): table_('A',_'J',_'M'),
#  ('A', 'J', 'N'): table_('A',_'J',_'N'),
#  ('A', 'J', 'O'): table_('A',_'J',_'O'),
#  ('A', 'J', 'P'): table_('A',_'J',_'P'),
#  ('A', 'J', 'Q'): table_('A',_'J',_'Q'),
#  ('A', 'J', 'R'): table_('A',_'J',_'R'),
#  ('A', 'K', 'L'): table_('A',_'K',_'L'),
#  ('A', 'K', 'M'): table_('A',_'K',_'M'),
#  ('A', 'K', 'N'): table_('A',_'K',_'N'),
#  ('A', 'K', 'O'): table_('A',_'K',_'O'),
#  ('A', 'K', 'P'): table_('A',_'K',_'P'),
#  ('A', 'K', 'Q'): table_('A',_'K',_'Q'),
#  ('A', 'K', 'R'): table_('A',_'K',_'R'),
#  ('A', 'L', 'M'): table_('A',_'L',_'M'),
#  ('A', 'L', 'N'): table_('A',_'L',_'N'),
#  ('A', 'L', 'O'): table_('A',_'L',_'O'),
#  ('A', 'L', 'P'): table_('A',_'L',_'P'),
#  ('A', 'L', 'Q'): table_('A',_'L',_'Q'),
#  ('A', 'L', 'R'): table_('A',_'L',_'R'),
#  ('A', 'M', 'N'): table_('A',_'M',_'N'),
#  ('A', 'M', 'O'): table_('A',_'M',_'O'),
#  ('A', 'M', 'P'): table_('A',_'M',_'P'),
#  ('A', 'M', 'Q'): table_('A',_'M',_'Q'),
#  ('A', 'M', 'R'): table_('A',_'M',_'R'),
#  ('A', 'N', 'O'): table_('A',_'N',_'O'),
#  ('A', 'N', 'P'): table_('A',_'N',_'P'),
#  ('A', 'N', 'Q'): table_('A',_'N',_'Q'),
#  ('A', 'N', 'R'): table_('A',_'N',_'R'),
#  ('A', 'O', 'P'): table_('A',_'O',_'P'),
#  ('A', 'O', 'Q'): table_('A',_'O',_'Q'),
#  ('A', 'O', 'R'): table_('A',_'O',_'R'),
#  ('A', 'P', 'Q'): table_('A',_'P',_'Q'),
#  ('A', 'P', 'R'): table_('A',_'P',_'R'),
#  ('A', 'Q', 'R'): table_('A',_'Q',_'R'),
#  ('B', 'C', 'D'): table_('B',_'C',_'D'),
#  ('B', 'C', 'E'): table_('B',_'C',_'E'),
#  ('B', 'C', 'F'): table_('B',_'C',_'F'),
#  ('B', 'C', 'G'): table_('B',_'C',_'G'),
#  ('B', 'C', 'I'): table_('B',_'C',_'I'),
#  ('B', 'C', 'J'): table_('B',_'C',_'J'),
#  ('B', 'C', 'K'): table_('B',_'C',_'K'),
#  ('B', 'C', 'L'): table_('B',_'C',_'L'),
#  ('B', 'C', 'M'): table_('B',_'C',_'M'),
#  ('B', 'C', 'N'): table_('B',_'C',_'N'),
#  ('B', 'C', 'O'): table_('B',_'C',_'O'),
#  ('B', 'C', 'P'): table_('B',_'C',_'P'),
#  ('B', 'C', 'Q'): table_('B',_'C',_'Q'),
#  ('B', 'C', 'R'): table_('B',_'C',_'R'),
#  ('B', 'D', 'E'): table_('B',_'D',_'E'),
#  ('B', 'D', 'F'): table_('B',_'D',_'F'),
#  ('B', 'D', 'G'): table_('B',_'D',_'G'),
#  ('B', 'D', 'I'): table_('B',_'D',_'I'),
#  ('B', 'D', 'J'): table_('B',_'D',_'J'),
#  ('B', 'D', 'K'): table_('B',_'D',_'K'),
#  ('B', 'D', 'L'): table_('B',_'D',_'L'),
#  ('B', 'D', 'M'): table_('B',_'D',_'M'),
#  ('B', 'D', 'N'): table_('B',_'D',_'N'),
#  ('B', 'D', 'O'): table_('B',_'D',_'O'),
#  ('B', 'D', 'P'): table_('B',_'D',_'P'),
#  ('B', 'D', 'Q'): table_('B',_'D',_'Q'),
#  ('B', 'D', 'R'): table_('B',_'D',_'R'),
#  ('B', 'E', 'F'): table_('B',_'E',_'F'),
#  ('B', 'E', 'G'): table_('B',_'E',_'G'),
#  ('B', 'E', 'I'): table_('B',_'E',_'I'),
#  ('B', 'E', 'J'): table_('B',_'E',_'J'),
#  ('B', 'E', 'K'): table_('B',_'E',_'K'),
#  ('B', 'E', 'L'): table_('B',_'E',_'L'),
#  ('B', 'E', 'M'): table_('B',_'E',_'M'),
#  ('B', 'E', 'N'): table_('B',_'E',_'N'),
#  ('B', 'E', 'O'): table_('B',_'E',_'O'),
#  ('B', 'E', 'P'): table_('B',_'E',_'P'),
#  ('B', 'E', 'Q'): table_('B',_'E',_'Q'),
#  ('B', 'E', 'R'): table_('B',_'E',_'R'),
#  ('B', 'F', 'G'): table_('B',_'F',_'G'),
#  ('B', 'F', 'I'): table_('B',_'F',_'I'),
#  ('B', 'F', 'J'): table_('B',_'F',_'J'),
#  ('B', 'F', 'K'): table_('B',_'F',_'K'),
#  ('B', 'F', 'L'): table_('B',_'F',_'L'),
#  ('B', 'F', 'M'): table_('B',_'F',_'M'),
#  ('B', 'F', 'N'): table_('B',_'F',_'N'),
#  ('B', 'F', 'O'): table_('B',_'F',_'O'),
#  ('B', 'F', 'P'): table_('B',_'F',_'P'),
#  ('B', 'F', 'Q'): table_('B',_'F',_'Q'),
#  ('B', 'F', 'R'): table_('B',_'F',_'R'),
#  ('B', 'G', 'I'): table_('B',_'G',_'I'),
#  ('B', 'G', 'J'): table_('B',_'G',_'J'),
#  ('B', 'G', 'K'): table_('B',_'G',_'K'),
#  ('B', 'G', 'L'): table_('B',_'G',_'L'),
#  ('B', 'G', 'M'): table_('B',_'G',_'M'),
#  ('B', 'G', 'N'): table_('B',_'G',_'N'),
#  ('B', 'G', 'O'): table_('B',_'G',_'O'),
#  ('B', 'G', 'P'): table_('B',_'G',_'P'),
#  ('B', 'G', 'Q'): table_('B',_'G',_'Q'),
#  ('B', 'G', 'R'): table_('B',_'G',_'R'),
#  ('B', 'I', 'J'): table_('B',_'I',_'J'),
#  ('B', 'I', 'K'): table_('B',_'I',_'K'),
#  ('B', 'I', 'L'): table_('B',_'I',_'L'),
#  ('B', 'I', 'M'): table_('B',_'I',_'M'),
#  ('B', 'I', 'N'): table_('B',_'I',_'N'),
#  ('B', 'I', 'O'): table_('B',_'I',_'O'),
#  ('B', 'I', 'P'): table_('B',_'I',_'P'),
#  ('B', 'I', 'Q'): table_('B',_'I',_'Q'),
#  ('B', 'I', 'R'): table_('B',_'I',_'R'),
#  ('B', 'J', 'K'): table_('B',_'J',_'K'),
#  ('B', 'J', 'L'): table_('B',_'J',_'L'),
#  ('B', 'J', 'M'): table_('B',_'J',_'M'),
#  ('B', 'J', 'N'): table_('B',_'J',_'N'),
#  ('B', 'J', 'O'): table_('B',_'J',_'O'),
#  ('B', 'J', 'P'): table_('B',_'J',_'P'),
#  ('B', 'J', 'Q'): table_('B',_'J',_'Q'),
#  ('B', 'J', 'R'): table_('B',_'J',_'R'),
#  ('B', 'K', 'L'): table_('B',_'K',_'L'),
#  ('B', 'K', 'M'): table_('B',_'K',_'M'),
#  ('B', 'K', 'N'): table_('B',_'K',_'N'),
#  ('B', 'K', 'O'): table_('B',_'K',_'O'),
#  ('B', 'K', 'P'): table_('B',_'K',_'P'),
#  ('B', 'K', 'Q'): table_('B',_'K',_'Q'),
#  ('B', 'K', 'R'): table_('B',_'K',_'R'),
#  ('B', 'L', 'M'): table_('B',_'L',_'M'),
#  ('B', 'L', 'N'): table_('B',_'L',_'N'),
#  ('B', 'L', 'O'): table_('B',_'L',_'O'),
#  ('B', 'L', 'P'): table_('B',_'L',_'P'),
#  ('B', 'L', 'Q'): table_('B',_'L',_'Q'),
#  ('B', 'L', 'R'): table_('B',_'L',_'R'),
#  ('B', 'M', 'N'): table_('B',_'M',_'N'),
#  ('B', 'M', 'O'): table_('B',_'M',_'O'),
#  ('B', 'M', 'P'): table_('B',_'M',_'P'),
#  ('B', 'M', 'Q'): table_('B',_'M',_'Q'),
#  ('B', 'M', 'R'): table_('B',_'M',_'R'),
#  ('B', 'N', 'O'): table_('B',_'N',_'O'),
#  ('B', 'N', 'P'): table_('B',_'N',_'P'),
#  ('B', 'N', 'Q'): table_('B',_'N',_'Q'),
#  ('B', 'N', 'R'): table_('B',_'N',_'R'),
#  ('B', 'O', 'P'): table_('B',_'O',_'P'),
#  ('B', 'O', 'Q'): table_('B',_'O',_'Q'),
#  ('B', 'O', 'R'): table_('B',_'O',_'R'),
#  ('B', 'P', 'Q'): table_('B',_'P',_'Q'),
#  ('B', 'P', 'R'): table_('B',_'P',_'R'),
#  ('B', 'Q', 'R'): table_('B',_'Q',_'R'),
#  ('C', 'D', 'E'): table_('C',_'D',_'E'),
#  ('C', 'D', 'F'): table_('C',_'D',_'F'),
#  ('C', 'D', 'G'): table_('C',_'D',_'G'),
#  ('C', 'D', 'I'): table_('C',_'D',_'I'),
#  ('C', 'D', 'J'): table_('C',_'D',_'J'),
#  ('C', 'D', 'K'): table_('C',_'D',_'K'),
#  ('C', 'D', 'L'): table_('C',_'D',_'L'),
#  ('C', 'D', 'M'): table_('C',_'D',_'M'),
#  ('C', 'D', 'N'): table_('C',_'D',_'N'),
#  ('C', 'D', 'O'): table_('C',_'D',_'O'),
#  ('C', 'D', 'P'): table_('C',_'D',_'P'),
#  ('C', 'D', 'Q'): table_('C',_'D',_'Q'),
#  ('C', 'D', 'R'): table_('C',_'D',_'R'),
#  ('C', 'E', 'F'): table_('C',_'E',_'F'),
#  ('C', 'E', 'G'): table_('C',_'E',_'G'),
#  ('C', 'E', 'I'): table_('C',_'E',_'I'),
#  ('C', 'E', 'J'): table_('C',_'E',_'J'),
#  ('C', 'E', 'K'): table_('C',_'E',_'K'),
#  ('C', 'E', 'L'): table_('C',_'E',_'L'),
#  ('C', 'E', 'M'): table_('C',_'E',_'M'),
#  ('C', 'E', 'N'): table_('C',_'E',_'N'),
#  ('C', 'E', 'O'): table_('C',_'E',_'O'),
#  ('C', 'E', 'P'): table_('C',_'E',_'P'),
#  ('C', 'E', 'Q'): table_('C',_'E',_'Q'),
#  ('C', 'E', 'R'): table_('C',_'E',_'R'),
#  ('C', 'F', 'G'): table_('C',_'F',_'G'),
#  ('C', 'F', 'I'): table_('C',_'F',_'I'),
#  ('C', 'F', 'J'): table_('C',_'F',_'J'),
#  ('C', 'F', 'K'): table_('C',_'F',_'K'),
#  ('C', 'F', 'L'): table_('C',_'F',_'L'),
#  ('C', 'F', 'M'): table_('C',_'F',_'M'),
#  ('C', 'F', 'N'): table_('C',_'F',_'N'),
#  ('C', 'F', 'O'): table_('C',_'F',_'O'),
#  ('C', 'F', 'P'): table_('C',_'F',_'P'),
#  ('C', 'F', 'Q'): table_('C',_'F',_'Q'),
#  ('C', 'F', 'R'): table_('C',_'F',_'R'),
#  ('C', 'G', 'I'): table_('C',_'G',_'I'),
#  ('C', 'G', 'J'): table_('C',_'G',_'J'),
#  ('C', 'G', 'K'): table_('C',_'G',_'K'),
#  ('C', 'G', 'L'): table_('C',_'G',_'L'),
#  ('C', 'G', 'M'): table_('C',_'G',_'M'),
#  ('C', 'G', 'N'): table_('C',_'G',_'N'),
#  ('C', 'G', 'O'): table_('C',_'G',_'O'),
#  ('C', 'G', 'P'): table_('C',_'G',_'P'),
#  ('C', 'G', 'Q'): table_('C',_'G',_'Q'),
#  ('C', 'G', 'R'): table_('C',_'G',_'R'),
#  ('C', 'I', 'J'): table_('C',_'I',_'J'),
#  ('C', 'I', 'K'): table_('C',_'I',_'K'),
#  ('C', 'I', 'L'): table_('C',_'I',_'L'),
#  ('C', 'I', 'M'): table_('C',_'I',_'M'),
#  ('C', 'I', 'N'): table_('C',_'I',_'N'),
#  ('C', 'I', 'O'): table_('C',_'I',_'O'),
#  ('C', 'I', 'P'): table_('C',_'I',_'P'),
#  ('C', 'I', 'Q'): table_('C',_'I',_'Q'),
#  ('C', 'I', 'R'): table_('C',_'I',_'R'),
#  ('C', 'J', 'K'): table_('C',_'J',_'K'),
#  ('C', 'J', 'L'): table_('C',_'J',_'L'),
#  ('C', 'J', 'M'): table_('C',_'J',_'M'),
#  ('C', 'J', 'N'): table_('C',_'J',_'N'),
#  ('C', 'J', 'O'): table_('C',_'J',_'O'),
#  ('C', 'J', 'P'): table_('C',_'J',_'P'),
#  ('C', 'J', 'Q'): table_('C',_'J',_'Q'),
#  ('C', 'J', 'R'): table_('C',_'J',_'R'),
#  ('C', 'K', 'L'): table_('C',_'K',_'L'),
#  ('C', 'K', 'M'): table_('C',_'K',_'M'),
#  ('C', 'K', 'N'): table_('C',_'K',_'N'),
#  ('C', 'K', 'O'): table_('C',_'K',_'O'),
#  ('C', 'K', 'P'): table_('C',_'K',_'P'),
#  ('C', 'K', 'Q'): table_('C',_'K',_'Q'),
#  ('C', 'K', 'R'): table_('C',_'K',_'R'),
#  ('C', 'L', 'M'): table_('C',_'L',_'M'),
#  ('C', 'L', 'N'): table_('C',_'L',_'N'),
#  ('C', 'L', 'O'): table_('C',_'L',_'O'),
#  ('C', 'L', 'P'): table_('C',_'L',_'P'),
#  ('C', 'L', 'Q'): table_('C',_'L',_'Q'),
#  ('C', 'L', 'R'): table_('C',_'L',_'R'),
#  ('C', 'M', 'N'): table_('C',_'M',_'N'),
#  ('C', 'M', 'O'): table_('C',_'M',_'O'),
#  ('C', 'M', 'P'): table_('C',_'M',_'P'),
#  ('C', 'M', 'Q'): table_('C',_'M',_'Q'),
#  ('C', 'M', 'R'): table_('C',_'M',_'R'),
#  ('C', 'N', 'O'): table_('C',_'N',_'O'),
#  ('C', 'N', 'P'): table_('C',_'N',_'P'),
#  ('C', 'N', 'Q'): table_('C',_'N',_'Q'),
#  ('C', 'N', 'R'): table_('C',_'N',_'R'),
#  ('C', 'O', 'P'): table_('C',_'O',_'P'),
#  ('C', 'O', 'Q'): table_('C',_'O',_'Q'),
#  ('C', 'O', 'R'): table_('C',_'O',_'R'),
#  ('C', 'P', 'Q'): table_('C',_'P',_'Q'),
#  ('C', 'P', 'R'): table_('C',_'P',_'R'),
#  ('C', 'Q', 'R'): table_('C',_'Q',_'R'),
#  ('D', 'E', 'F'): table_('D',_'E',_'F'),
#  ('D', 'E', 'G'): table_('D',_'E',_'G'),
#  ('D', 'E', 'I'): table_('D',_'E',_'I'),
#  ('D', 'E', 'J'): table_('D',_'E',_'J'),
#  ('D', 'E', 'K'): table_('D',_'E',_'K'),
#  ('D', 'E', 'L'): table_('D',_'E',_'L'),
#  ('D', 'E', 'M'): table_('D',_'E',_'M'),
#  ('D', 'E', 'N'): table_('D',_'E',_'N'),
#  ('D', 'E', 'O'): table_('D',_'E',_'O'),
#  ('D', 'E', 'P'): table_('D',_'E',_'P'),
#  ('D', 'E', 'Q'): table_('D',_'E',_'Q'),
#  ('D', 'E', 'R'): table_('D',_'E',_'R'),
#  ('D', 'F', 'G'): table_('D',_'F',_'G'),
#  ('D', 'F', 'I'): table_('D',_'F',_'I'),
#  ('D', 'F', 'J'): table_('D',_'F',_'J'),
#  ('D', 'F', 'K'): table_('D',_'F',_'K'),
#  ('D', 'F', 'L'): table_('D',_'F',_'L'),
#  ('D', 'F', 'M'): table_('D',_'F',_'M'),
#  ('D', 'F', 'N'): table_('D',_'F',_'N'),
#  ('D', 'F', 'O'): table_('D',_'F',_'O'),
#  ('D', 'F', 'P'): table_('D',_'F',_'P'),
#  ('D', 'F', 'Q'): table_('D',_'F',_'Q'),
#  ('D', 'F', 'R'): table_('D',_'F',_'R'),
#  ('D', 'G', 'I'): table_('D',_'G',_'I'),
#  ('D', 'G', 'J'): table_('D',_'G',_'J'),
#  ('D', 'G', 'K'): table_('D',_'G',_'K'),
#  ('D', 'G', 'L'): table_('D',_'G',_'L'),
#  ('D', 'G', 'M'): table_('D',_'G',_'M'),
#  ('D', 'G', 'N'): table_('D',_'G',_'N'),
#  ('D', 'G', 'O'): table_('D',_'G',_'O'),
#  ('D', 'G', 'P'): table_('D',_'G',_'P'),
#  ('D', 'G', 'Q'): table_('D',_'G',_'Q'),
#  ('D', 'G', 'R'): table_('D',_'G',_'R'),
#  ('D', 'I', 'J'): table_('D',_'I',_'J'),
#  ('D', 'I', 'K'): table_('D',_'I',_'K'),
#  ('D', 'I', 'L'): table_('D',_'I',_'L'),
#  ('D', 'I', 'M'): table_('D',_'I',_'M'),
#  ('D', 'I', 'N'): table_('D',_'I',_'N'),
#  ('D', 'I', 'O'): table_('D',_'I',_'O'),
#  ('D', 'I', 'P'): table_('D',_'I',_'P'),
#  ('D', 'I', 'Q'): table_('D',_'I',_'Q'),
#  ('D', 'I', 'R'): table_('D',_'I',_'R'),
#  ('D', 'J', 'K'): table_('D',_'J',_'K'),
#  ('D', 'J', 'L'): table_('D',_'J',_'L'),
#  ('D', 'J', 'M'): table_('D',_'J',_'M'),
#  ('D', 'J', 'N'): table_('D',_'J',_'N'),
#  ('D', 'J', 'O'): table_('D',_'J',_'O'),
#  ('D', 'J', 'P'): table_('D',_'J',_'P'),
#  ('D', 'J', 'Q'): table_('D',_'J',_'Q'),
#  ('D', 'J', 'R'): table_('D',_'J',_'R'),
#  ('D', 'K', 'L'): table_('D',_'K',_'L'),
#  ('D', 'K', 'M'): table_('D',_'K',_'M'),
#  ('D', 'K', 'N'): table_('D',_'K',_'N'),
#  ('D', 'K', 'O'): table_('D',_'K',_'O'),
#  ('D', 'K', 'P'): table_('D',_'K',_'P'),
#  ('D', 'K', 'Q'): table_('D',_'K',_'Q'),
#  ('D', 'K', 'R'): table_('D',_'K',_'R'),
#  ('D', 'L', 'M'): table_('D',_'L',_'M'),
#  ('D', 'L', 'N'): table_('D',_'L',_'N'),
#  ('D', 'L', 'O'): table_('D',_'L',_'O'),
#  ('D', 'L', 'P'): table_('D',_'L',_'P'),
#  ('D', 'L', 'Q'): table_('D',_'L',_'Q'),
#  ('D', 'L', 'R'): table_('D',_'L',_'R'),
#  ('D', 'M', 'N'): table_('D',_'M',_'N'),
#  ('D', 'M', 'O'): table_('D',_'M',_'O'),
#  ('D', 'M', 'P'): table_('D',_'M',_'P'),
#  ('D', 'M', 'Q'): table_('D',_'M',_'Q'),
#  ('D', 'M', 'R'): table_('D',_'M',_'R'),
#  ('D', 'N', 'O'): table_('D',_'N',_'O'),
#  ('D', 'N', 'P'): table_('D',_'N',_'P'),
#  ('D', 'N', 'Q'): table_('D',_'N',_'Q'),
#  ('D', 'N', 'R'): table_('D',_'N',_'R'),
#  ('D', 'O', 'P'): table_('D',_'O',_'P'),
#  ('D', 'O', 'Q'): table_('D',_'O',_'Q'),
#  ('D', 'O', 'R'): table_('D',_'O',_'R'),
#  ('D', 'P', 'Q'): table_('D',_'P',_'Q'),
#  ('D', 'P', 'R'): table_('D',_'P',_'R'),
#  ('D', 'Q', 'R'): table_('D',_'Q',_'R'),
#  ('E', 'F', 'G'): table_('E',_'F',_'G'),
#  ('E', 'F', 'I'): table_('E',_'F',_'I'),
#  ('E', 'F', 'J'): table_('E',_'F',_'J'),
#  ('E', 'F', 'K'): table_('E',_'F',_'K'),
#  ('E', 'F', 'L'): table_('E',_'F',_'L'),
#  ('E', 'F', 'M'): table_('E',_'F',_'M'),
#  ('E', 'F', 'N'): table_('E',_'F',_'N'),
#  ('E', 'F', 'O'): table_('E',_'F',_'O'),
#  ('E', 'F', 'P'): table_('E',_'F',_'P'),
#  ('E', 'F', 'Q'): table_('E',_'F',_'Q'),
#  ('E', 'F', 'R'): table_('E',_'F',_'R'),
#  ('E', 'G', 'I'): table_('E',_'G',_'I'),
#  ('E', 'G', 'J'): table_('E',_'G',_'J'),
#  ('E', 'G', 'K'): table_('E',_'G',_'K'),
#  ('E', 'G', 'L'): table_('E',_'G',_'L'),
#  ('E', 'G', 'M'): table_('E',_'G',_'M'),
#  ('E', 'G', 'N'): table_('E',_'G',_'N'),
#  ('E', 'G', 'O'): table_('E',_'G',_'O'),
#  ('E', 'G', 'P'): table_('E',_'G',_'P'),
#  ('E', 'G', 'Q'): table_('E',_'G',_'Q'),
#  ('E', 'G', 'R'): table_('E',_'G',_'R'),
#  ('E', 'I', 'J'): table_('E',_'I',_'J'),
#  ('E', 'I', 'K'): table_('E',_'I',_'K'),
#  ('E', 'I', 'L'): table_('E',_'I',_'L'),
#  ('E', 'I', 'M'): table_('E',_'I',_'M'),
#  ('E', 'I', 'N'): table_('E',_'I',_'N'),
#  ('E', 'I', 'O'): table_('E',_'I',_'O'),
#  ('E', 'I', 'P'): table_('E',_'I',_'P'),
#  ('E', 'I', 'Q'): table_('E',_'I',_'Q'),
#  ('E', 'I', 'R'): table_('E',_'I',_'R'),
#  ('E', 'J', 'K'): table_('E',_'J',_'K'),
#  ('E', 'J', 'L'): table_('E',_'J',_'L'),
#  ('E', 'J', 'M'): table_('E',_'J',_'M'),
#  ('E', 'J', 'N'): table_('E',_'J',_'N'),
#  ('E', 'J', 'O'): table_('E',_'J',_'O'),
#  ('E', 'J', 'P'): table_('E',_'J',_'P'),
#  ('E', 'J', 'Q'): table_('E',_'J',_'Q'),
#  ('E', 'J', 'R'): table_('E',_'J',_'R'),
#  ('E', 'K', 'L'): table_('E',_'K',_'L'),
#  ('E', 'K', 'M'): table_('E',_'K',_'M'),
#  ('E', 'K', 'N'): table_('E',_'K',_'N'),
#  ('E', 'K', 'O'): table_('E',_'K',_'O'),
#  ('E', 'K', 'P'): table_('E',_'K',_'P'),
#  ('E', 'K', 'Q'): table_('E',_'K',_'Q'),
#  ('E', 'K', 'R'): table_('E',_'K',_'R'),
#  ('E', 'L', 'M'): table_('E',_'L',_'M'),
#  ('E', 'L', 'N'): table_('E',_'L',_'N'),
#  ('E', 'L', 'O'): table_('E',_'L',_'O'),
#  ('E', 'L', 'P'): table_('E',_'L',_'P'),
#  ('E', 'L', 'Q'): table_('E',_'L',_'Q'),
#  ('E', 'L', 'R'): table_('E',_'L',_'R'),
#  ('E', 'M', 'N'): table_('E',_'M',_'N'),
#  ('E', 'M', 'O'): table_('E',_'M',_'O'),
#  ('E', 'M', 'P'): table_('E',_'M',_'P'),
#  ('E', 'M', 'Q'): table_('E',_'M',_'Q'),
#  ('E', 'M', 'R'): table_('E',_'M',_'R'),
#  ('E', 'N', 'O'): table_('E',_'N',_'O'),
#  ('E', 'N', 'P'): table_('E',_'N',_'P'),
#  ('E', 'N', 'Q'): table_('E',_'N',_'Q'),
#  ('E', 'N', 'R'): table_('E',_'N',_'R'),
#  ('E', 'O', 'P'): table_('E',_'O',_'P'),
#  ('E', 'O', 'Q'): table_('E',_'O',_'Q'),
#  ('E', 'O', 'R'): table_('E',_'O',_'R'),
#  ('E', 'P', 'Q'): table_('E',_'P',_'Q'),
#  ('E', 'P', 'R'): table_('E',_'P',_'R'),
#  ('E', 'Q', 'R'): table_('E',_'Q',_'R'),
#  ('F', 'G', 'I'): table_('F',_'G',_'I'),
#  ('F', 'G', 'J'): table_('F',_'G',_'J'),
#  ('F', 'G', 'K'): table_('F',_'G',_'K'),
#  ('F', 'G', 'L'): table_('F',_'G',_'L'),
#  ('F', 'G', 'M'): table_('F',_'G',_'M'),
#  ('F', 'G', 'N'): table_('F',_'G',_'N'),
#  ('F', 'G', 'O'): table_('F',_'G',_'O'),
#  ('F', 'G', 'P'): table_('F',_'G',_'P'),
#  ('F', 'G', 'Q'): table_('F',_'G',_'Q'),
#  ('F', 'G', 'R'): table_('F',_'G',_'R'),
#  ('F', 'I', 'J'): table_('F',_'I',_'J'),
#  ('F', 'I', 'K'): table_('F',_'I',_'K'),
#  ('F', 'I', 'L'): table_('F',_'I',_'L'),
#  ('F', 'I', 'M'): table_('F',_'I',_'M'),
#  ('F', 'I', 'N'): table_('F',_'I',_'N'),
#  ('F', 'I', 'O'): table_('F',_'I',_'O'),
#  ('F', 'I', 'P'): table_('F',_'I',_'P'),
#  ('F', 'I', 'Q'): table_('F',_'I',_'Q'),
#  ('F', 'I', 'R'): table_('F',_'I',_'R'),
#  ('F', 'J', 'K'): table_('F',_'J',_'K'),
#  ('F', 'J', 'L'): table_('F',_'J',_'L'),
#  ('F', 'J', 'M'): table_('F',_'J',_'M'),
#  ('F', 'J', 'N'): table_('F',_'J',_'N'),
#  ('F', 'J', 'O'): table_('F',_'J',_'O'),
#  ('F', 'J', 'P'): table_('F',_'J',_'P'),
#  ('F', 'J', 'Q'): table_('F',_'J',_'Q'),
#  ('F', 'J', 'R'): table_('F',_'J',_'R'),
#  ('F', 'K', 'L'): table_('F',_'K',_'L'),
#  ('F', 'K', 'M'): table_('F',_'K',_'M'),
#  ('F', 'K', 'N'): table_('F',_'K',_'N'),
#  ('F', 'K', 'O'): table_('F',_'K',_'O'),
#  ('F', 'K', 'P'): table_('F',_'K',_'P'),
#  ('F', 'K', 'Q'): table_('F',_'K',_'Q'),
#  ('F', 'K', 'R'): table_('F',_'K',_'R'),
#  ('F', 'L', 'M'): table_('F',_'L',_'M'),
#  ('F', 'L', 'N'): table_('F',_'L',_'N'),
#  ('F', 'L', 'O'): table_('F',_'L',_'O'),
#  ('F', 'L', 'P'): table_('F',_'L',_'P'),
#  ('F', 'L', 'Q'): table_('F',_'L',_'Q'),
#  ('F', 'L', 'R'): table_('F',_'L',_'R'),
#  ('F', 'M', 'N'): table_('F',_'M',_'N'),
#  ('F', 'M', 'O'): table_('F',_'M',_'O'),
#  ('F', 'M', 'P'): table_('F',_'M',_'P'),
#  ('F', 'M', 'Q'): table_('F',_'M',_'Q'),
#  ('F', 'M', 'R'): table_('F',_'M',_'R'),
#  ('F', 'N', 'O'): table_('F',_'N',_'O'),
#  ('F', 'N', 'P'): table_('F',_'N',_'P'),
#  ('F', 'N', 'Q'): table_('F',_'N',_'Q'),
#  ('F', 'N', 'R'): table_('F',_'N',_'R'),
#  ('F', 'O', 'P'): table_('F',_'O',_'P'),
#  ('F', 'O', 'Q'): table_('F',_'O',_'Q'),
#  ('F', 'O', 'R'): table_('F',_'O',_'R'),
#  ('F', 'P', 'Q'): table_('F',_'P',_'Q'),
#  ('F', 'P', 'R'): table_('F',_'P',_'R'),
#  ('F', 'Q', 'R'): table_('F',_'Q',_'R'),
#  ('G', 'I', 'J'): table_('G',_'I',_'J'),
#  ('G', 'I', 'K'): table_('G',_'I',_'K'),
#  ('G', 'I', 'L'): table_('G',_'I',_'L'),
#  ('G', 'I', 'M'): table_('G',_'I',_'M'),
#  ('G', 'I', 'N'): table_('G',_'I',_'N'),
#  ('G', 'I', 'O'): table_('G',_'I',_'O'),
#  ('G', 'I', 'P'): table_('G',_'I',_'P'),
#  ('G', 'I', 'Q'): table_('G',_'I',_'Q'),
#  ('G', 'I', 'R'): table_('G',_'I',_'R'),
#  ('G', 'J', 'K'): table_('G',_'J',_'K'),
#  ('G', 'J', 'L'): table_('G',_'J',_'L'),
#  ('G', 'J', 'M'): table_('G',_'J',_'M'),
#  ('G', 'J', 'N'): table_('G',_'J',_'N'),
#  ('G', 'J', 'O'): table_('G',_'J',_'O'),
#  ('G', 'J', 'P'): table_('G',_'J',_'P'),
#  ('G', 'J', 'Q'): table_('G',_'J',_'Q'),
#  ('G', 'J', 'R'): table_('G',_'J',_'R'),
#  ('G', 'K', 'L'): table_('G',_'K',_'L'),
#  ('G', 'K', 'M'): table_('G',_'K',_'M'),
#  ('G', 'K', 'N'): table_('G',_'K',_'N'),
#  ('G', 'K', 'O'): table_('G',_'K',_'O'),
#  ('G', 'K', 'P'): table_('G',_'K',_'P'),
#  ('G', 'K', 'Q'): table_('G',_'K',_'Q'),
#  ('G', 'K', 'R'): table_('G',_'K',_'R'),
#  ('G', 'L', 'M'): table_('G',_'L',_'M'),
#  ('G', 'L', 'N'): table_('G',_'L',_'N'),
#  ('G', 'L', 'O'): table_('G',_'L',_'O'),
#  ('G', 'L', 'P'): table_('G',_'L',_'P'),
#  ('G', 'L', 'Q'): table_('G',_'L',_'Q'),
#  ('G', 'L', 'R'): table_('G',_'L',_'R'),
#  ('G', 'M', 'N'): table_('G',_'M',_'N'),
#  ('G', 'M', 'O'): table_('G',_'M',_'O'),
#  ('G', 'M', 'P'): table_('G',_'M',_'P'),
#  ('G', 'M', 'Q'): table_('G',_'M',_'Q'),
#  ('G', 'M', 'R'): table_('G',_'M',_'R'),
#  ('G', 'N', 'O'): table_('G',_'N',_'O'),
#  ('G', 'N', 'P'): table_('G',_'N',_'P'),
#  ('G', 'N', 'Q'): table_('G',_'N',_'Q'),
#  ('G', 'N', 'R'): table_('G',_'N',_'R'),
#  ('G', 'O', 'P'): table_('G',_'O',_'P'),
#  ('G', 'O', 'Q'): table_('G',_'O',_'Q'),
#  ('G', 'O', 'R'): table_('G',_'O',_'R'),
#  ('G', 'P', 'Q'): table_('G',_'P',_'Q'),
#  ('G', 'P', 'R'): table_('G',_'P',_'R'),
#  ('G', 'Q', 'R'): table_('G',_'Q',_'R'),
#  ('I', 'J', 'K'): table_('I',_'J',_'K'),
#  ('I', 'J', 'L'): table_('I',_'J',_'L'),
#  ('I', 'J', 'M'): table_('I',_'J',_'M'),
#  ('I', 'J', 'N'): table_('I',_'J',_'N'),
#  ('I', 'J', 'O'): table_('I',_'J',_'O'),
#  ('I', 'J', 'P'): table_('I',_'J',_'P'),
#  ('I', 'J', 'Q'): table_('I',_'J',_'Q'),
#  ('I', 'J', 'R'): table_('I',_'J',_'R'),
#  ('I', 'K', 'L'): table_('I',_'K',_'L'),
#  ('I', 'K', 'M'): table_('I',_'K',_'M'),
#  ('I', 'K', 'N'): table_('I',_'K',_'N'),
#  ('I', 'K', 'O'): table_('I',_'K',_'O'),
#  ('I', 'K', 'P'): table_('I',_'K',_'P'),
#  ('I', 'K', 'Q'): table_('I',_'K',_'Q'),
#  ('I', 'K', 'R'): table_('I',_'K',_'R'),
#  ('I', 'L', 'M'): table_('I',_'L',_'M'),
#  ('I', 'L', 'N'): table_('I',_'L',_'N'),
#  ('I', 'L', 'O'): table_('I',_'L',_'O'),
#  ('I', 'L', 'P'): table_('I',_'L',_'P'),
#  ('I', 'L', 'Q'): table_('I',_'L',_'Q'),
#  ('I', 'L', 'R'): table_('I',_'L',_'R'),
#  ('I', 'M', 'N'): table_('I',_'M',_'N'),
#  ('I', 'M', 'O'): table_('I',_'M',_'O'),
#  ('I', 'M', 'P'): table_('I',_'M',_'P'),
#  ('I', 'M', 'Q'): table_('I',_'M',_'Q'),
#  ('I', 'M', 'R'): table_('I',_'M',_'R'),
#  ('I', 'N', 'O'): table_('I',_'N',_'O'),
#  ('I', 'N', 'P'): table_('I',_'N',_'P'),
#  ('I', 'N', 'Q'): table_('I',_'N',_'Q'),
#  ('I', 'N', 'R'): table_('I',_'N',_'R'),
#  ('I', 'O', 'P'): table_('I',_'O',_'P'),
#  ('I', 'O', 'Q'): table_('I',_'O',_'Q'),
#  ('I', 'O', 'R'): table_('I',_'O',_'R'),
#  ('I', 'P', 'Q'): table_('I',_'P',_'Q'),
#  ('I', 'P', 'R'): table_('I',_'P',_'R'),
#  ('I', 'Q', 'R'): table_('I',_'Q',_'R'),
#  ('J', 'K', 'L'): table_('J',_'K',_'L'),
#  ('J', 'K', 'M'): table_('J',_'K',_'M'),
#  ('J', 'K', 'N'): table_('J',_'K',_'N'),
#  ('J', 'K', 'O'): table_('J',_'K',_'O'),
#  ('J', 'K', 'P'): table_('J',_'K',_'P'),
#  ('J', 'K', 'Q'): table_('J',_'K',_'Q'),
#  ('J', 'K', 'R'): table_('J',_'K',_'R'),
#  ('J', 'L', 'M'): table_('J',_'L',_'M'),
#  ('J', 'L', 'N'): table_('J',_'L',_'N'),
#  ('J', 'L', 'O'): table_('J',_'L',_'O'),
#  ('J', 'L', 'P'): table_('J',_'L',_'P'),
#  ('J', 'L', 'Q'): table_('J',_'L',_'Q'),
#  ('J', 'L', 'R'): table_('J',_'L',_'R'),
#  ('J', 'M', 'N'): table_('J',_'M',_'N'),
#  ('J', 'M', 'O'): table_('J',_'M',_'O'),
#  ('J', 'M', 'P'): table_('J',_'M',_'P'),
#  ('J', 'M', 'Q'): table_('J',_'M',_'Q'),
#  ('J', 'M', 'R'): table_('J',_'M',_'R'),
#  ('J', 'N', 'O'): table_('J',_'N',_'O'),
#  ('J', 'N', 'P'): table_('J',_'N',_'P'),
#  ('J', 'N', 'Q'): table_('J',_'N',_'Q'),
#  ('J', 'N', 'R'): table_('J',_'N',_'R'),
#  ('J', 'O', 'P'): table_('J',_'O',_'P'),
#  ('J', 'O', 'Q'): table_('J',_'O',_'Q'),
#  ('J', 'O', 'R'): table_('J',_'O',_'R'),
#  ('J', 'P', 'Q'): table_('J',_'P',_'Q'),
#  ('J', 'P', 'R'): table_('J',_'P',_'R'),
#  ('J', 'Q', 'R'): table_('J',_'Q',_'R'),
#  ('K', 'L', 'M'): table_('K',_'L',_'M'),
#  ('K', 'L', 'N'): table_('K',_'L',_'N'),
#  ('K', 'L', 'O'): table_('K',_'L',_'O'),
#  ('K', 'L', 'P'): table_('K',_'L',_'P'),
#  ('K', 'L', 'Q'): table_('K',_'L',_'Q'),
#  ('K', 'L', 'R'): table_('K',_'L',_'R'),
#  ('K', 'M', 'N'): table_('K',_'M',_'N'),
#  ('K', 'M', 'O'): table_('K',_'M',_'O'),
#  ('K', 'M', 'P'): table_('K',_'M',_'P'),
#  ('K', 'M', 'Q'): table_('K',_'M',_'Q'),
#  ('K', 'M', 'R'): table_('K',_'M',_'R'),
#  ('K', 'N', 'O'): table_('K',_'N',_'O'),
#  ('K', 'N', 'P'): table_('K',_'N',_'P'),
#  ('K', 'N', 'Q'): table_('K',_'N',_'Q'),
#  ('K', 'N', 'R'): table_('K',_'N',_'R'),
#  ('K', 'O', 'P'): table_('K',_'O',_'P'),
#  ('K', 'O', 'Q'): table_('K',_'O',_'Q'),
#  ('K', 'O', 'R'): table_('K',_'O',_'R'),
#  ('K', 'P', 'Q'): table_('K',_'P',_'Q'),
#  ('K', 'P', 'R'): table_('K',_'P',_'R'),
#  ('K', 'Q', 'R'): table_('K',_'Q',_'R'),
#  ('L', 'M', 'N'): table_('L',_'M',_'N'),
#  ('L', 'M', 'O'): table_('L',_'M',_'O'),
#  ('L', 'M', 'P'): table_('L',_'M',_'P'),
#  ('L', 'M', 'Q'): table_('L',_'M',_'Q'),
#  ('L', 'M', 'R'): table_('L',_'M',_'R'),
#  ('L', 'N', 'O'): table_('L',_'N',_'O'),
#  ('L', 'N', 'P'): table_('L',_'N',_'P'),
#  ('L', 'N', 'Q'): table_('L',_'N',_'Q'),
#  ('L', 'N', 'R'): table_('L',_'N',_'R'),
#  ('L', 'O', 'P'): table_('L',_'O',_'P'),
#  ('L', 'O', 'Q'): table_('L',_'O',_'Q'),
#  ('L', 'O', 'R'): table_('L',_'O',_'R'),
#  ('L', 'P', 'Q'): table_('L',_'P',_'Q'),
#  ('L', 'P', 'R'): table_('L',_'P',_'R'),
#  ('L', 'Q', 'R'): table_('L',_'Q',_'R'),
#  ('M', 'N', 'O'): table_('M',_'N',_'O'),
#  ('M', 'N', 'P'): table_('M',_'N',_'P'),
#  ('M', 'N', 'Q'): table_('M',_'N',_'Q'),
#  ('M', 'N', 'R'): table_('M',_'N',_'R'),
#  ('M', 'O', 'P'): table_('M',_'O',_'P'),
#  ('M', 'O', 'Q'): table_('M',_'O',_'Q'),
#  ('M', 'O', 'R'): table_('M',_'O',_'R'),
#  ('M', 'P', 'Q'): table_('M',_'P',_'Q'),
#  ('M', 'P', 'R'): table_('M',_'P',_'R'),
#  ('M', 'Q', 'R'): table_('M',_'Q',_'R'),
#  ('N', 'O', 'P'): table_('N',_'O',_'P'),
#  ('N', 'O', 'Q'): table_('N',_'O',_'Q'),
#  ('N', 'O', 'R'): table_('N',_'O',_'R'),
#  ('N', 'P', 'Q'): table_('N',_'P',_'Q'),
#  ('N', 'P', 'R'): table_('N',_'P',_'R'),
#  ('N', 'Q', 'R'): table_('N',_'Q',_'R'),
#  ('O', 'P', 'Q'): table_('O',_'P',_'Q'),
#  ('O', 'P', 'R'): table_('O',_'P',_'R'),
#  ('O', 'Q', 'R'): table_('O',_'Q',_'R'),
#  ('P', 'Q', 'R'): table_('P',_'Q',_'R'),
#  ('A', 'B', 'C', 'D'): table_('A',_'B',_'C',_'D'),
#  ('A', 'B', 'C', 'E'): table_('A',_'B',_'C',_'E'),
#  ('A', 'B', 'C', 'F'): table_('A',_'B',_'C',_'F'),
#  ('A', 'B', 'C', 'G'): table_('A',_'B',_'C',_'G'),
#  ('A', 'B', 'C', 'I'): table_('A',_'B',_'C',_'I'),
#  ('A', 'B', 'C', 'J'): table_('A',_'B',_'C',_'J'),
#  ('A', 'B', 'C', 'K'): table_('A',_'B',_'C',_'K'),
#  ('A', 'B', 'C', 'L'): table_('A',_'B',_'C',_'L'),
#  ('A', 'B', 'C', 'M'): table_('A',_'B',_'C',_'M'),
#  ('A', 'B', 'C', 'N'): table_('A',_'B',_'C',_'N'),
#  ('A', 'B', 'C', 'O'): table_('A',_'B',_'C',_'O'),
#  ('A', 'B', 'C', 'P'): table_('A',_'B',_'C',_'P'),
#  ('A', 'B', 'C', 'Q'): table_('A',_'B',_'C',_'Q'),
#  ('A', 'B', 'C', 'R'): table_('A',_'B',_'C',_'R'),
#  ('A', 'B', 'D', 'E'): table_('A',_'B',_'D',_'E'),
#  ('A', 'B', 'D', 'F'): table_('A',_'B',_'D',_'F'),
#  ('A', 'B', 'D', 'G'): table_('A',_'B',_'D',_'G'),
#  ('A', 'B', 'D', 'I'): table_('A',_'B',_'D',_'I'),
#  ('A', 'B', 'D', 'J'): table_('A',_'B',_'D',_'J'),
#  ('A', 'B', 'D', 'K'): table_('A',_'B',_'D',_'K'),
#  ('A', 'B', 'D', 'L'): table_('A',_'B',_'D',_'L'),
#  ('A', 'B', 'D', 'M'): table_('A',_'B',_'D',_'M'),
#  ('A', 'B', 'D', 'N'): table_('A',_'B',_'D',_'N'),
#  ('A', 'B', 'D', 'O'): table_('A',_'B',_'D',_'O'),
#  ('A', 'B', 'D', 'P'): table_('A',_'B',_'D',_'P'),
#  ('A', 'B', 'D', 'Q'): table_('A',_'B',_'D',_'Q'),
#  ('A', 'B', 'D', 'R'): table_('A',_'B',_'D',_'R'),
#  ('A', 'B', 'E', 'F'): table_('A',_'B',_'E',_'F'),
#  ('A', 'B', 'E', 'G'): table_('A',_'B',_'E',_'G'),
#  ('A', 'B', 'E', 'I'): table_('A',_'B',_'E',_'I'),
#  ('A', 'B', 'E', 'J'): table_('A',_'B',_'E',_'J'),
#  ('A', 'B', 'E', 'K'): table_('A',_'B',_'E',_'K'),
#  ('A', 'B', 'E', 'L'): table_('A',_'B',_'E',_'L'),
#  ('A', 'B', 'E', 'M'): table_('A',_'B',_'E',_'M'),
#  ('A', 'B', 'E', 'N'): table_('A',_'B',_'E',_'N'),
#  ('A', 'B', 'E', 'O'): table_('A',_'B',_'E',_'O'),
#  ('A', 'B', 'E', 'P'): table_('A',_'B',_'E',_'P'),
#  ('A', 'B', 'E', 'Q'): table_('A',_'B',_'E',_'Q'),
#  ('A', 'B', 'E', 'R'): table_('A',_'B',_'E',_'R'),
#  ('A', 'B', 'F', 'G'): table_('A',_'B',_'F',_'G'),
#  ('A', 'B', 'F', 'I'): table_('A',_'B',_'F',_'I'),
#  ('A', 'B', 'F', 'J'): table_('A',_'B',_'F',_'J'),
#  ('A', 'B', 'F', 'K'): table_('A',_'B',_'F',_'K'),
#  ('A', 'B', 'F', 'L'): table_('A',_'B',_'F',_'L'),
#  ('A', 'B', 'F', 'M'): table_('A',_'B',_'F',_'M'),
#  ('A', 'B', 'F', 'N'): table_('A',_'B',_'F',_'N'),
#  ('A', 'B', 'F', 'O'): table_('A',_'B',_'F',_'O'),
#  ('A', 'B', 'F', 'P'): table_('A',_'B',_'F',_'P'),
#  ('A', 'B', 'F', 'Q'): table_('A',_'B',_'F',_'Q'),
#  ('A', 'B', 'F', 'R'): table_('A',_'B',_'F',_'R'),
#  ('A', 'B', 'G', 'I'): table_('A',_'B',_'G',_'I'),
#  ('A', 'B', 'G', 'J'): table_('A',_'B',_'G',_'J'),
#  ('A', 'B', 'G', 'K'): table_('A',_'B',_'G',_'K'),
#  ('A', 'B', 'G', 'L'): table_('A',_'B',_'G',_'L'),
#  ('A', 'B', 'G', 'M'): table_('A',_'B',_'G',_'M'),
#  ('A', 'B', 'G', 'N'): table_('A',_'B',_'G',_'N'),
#  ('A', 'B', 'G', 'O'): table_('A',_'B',_'G',_'O'),
#  ('A', 'B', 'G', 'P'): table_('A',_'B',_'G',_'P'),
#  ('A', 'B', 'G', 'Q'): table_('A',_'B',_'G',_'Q'),
#  ('A', 'B', 'G', 'R'): table_('A',_'B',_'G',_'R'),
#  ('A', 'B', 'I', 'J'): table_('A',_'B',_'I',_'J'),
#  ('A', 'B', 'I', 'K'): table_('A',_'B',_'I',_'K'),
#  ('A', 'B', 'I', 'L'): table_('A',_'B',_'I',_'L'),
#  ('A', 'B', 'I', 'M'): table_('A',_'B',_'I',_'M'),
#  ('A', 'B', 'I', 'N'): table_('A',_'B',_'I',_'N'),
#  ('A', 'B', 'I', 'O'): table_('A',_'B',_'I',_'O'),
#  ('A', 'B', 'I', 'P'): table_('A',_'B',_'I',_'P'),
#  ('A', 'B', 'I', 'Q'): table_('A',_'B',_'I',_'Q'),
#  ('A', 'B', 'I', 'R'): table_('A',_'B',_'I',_'R'),
#  ('A', 'B', 'J', 'K'): table_('A',_'B',_'J',_'K'),
#  ('A', 'B', 'J', 'L'): table_('A',_'B',_'J',_'L'),
#  ('A', 'B', 'J', 'M'): table_('A',_'B',_'J',_'M'),
#  ('A', 'B', 'J', 'N'): table_('A',_'B',_'J',_'N'),
#  ('A', 'B', 'J', 'O'): table_('A',_'B',_'J',_'O'),
#  ('A', 'B', 'J', 'P'): table_('A',_'B',_'J',_'P'),
#  ('A', 'B', 'J', 'Q'): table_('A',_'B',_'J',_'Q'),
#  ('A', 'B', 'J', 'R'): table_('A',_'B',_'J',_'R'),
#  ('A', 'B', 'K', 'L'): table_('A',_'B',_'K',_'L'),
#  ('A', 'B', 'K', 'M'): table_('A',_'B',_'K',_'M'),
#  ('A', 'B', 'K', 'N'): table_('A',_'B',_'K',_'N'),
#  ('A', 'B', 'K', 'O'): table_('A',_'B',_'K',_'O'),
#  ('A', 'B', 'K', 'P'): table_('A',_'B',_'K',_'P'),
#  ('A', 'B', 'K', 'Q'): table_('A',_'B',_'K',_'Q'),
#  ('A', 'B', 'K', 'R'): table_('A',_'B',_'K',_'R'),
#  ('A', 'B', 'L', 'M'): table_('A',_'B',_'L',_'M'),
#  ('A', 'B', 'L', 'N'): table_('A',_'B',_'L',_'N'),
#  ('A', 'B', 'L', 'O'): table_('A',_'B',_'L',_'O'),
#  ('A', 'B', 'L', 'P'): table_('A',_'B',_'L',_'P'),
#  ('A', 'B', 'L', 'Q'): table_('A',_'B',_'L',_'Q'),
#  ('A', 'B', 'L', 'R'): table_('A',_'B',_'L',_'R'),
#  ('A', 'B', 'M', 'N'): table_('A',_'B',_'M',_'N'),
#  ('A', 'B', 'M', 'O'): table_('A',_'B',_'M',_'O'),
#  ('A', 'B', 'M', 'P'): table_('A',_'B',_'M',_'P'),
#  ('A', 'B', 'M', 'Q'): table_('A',_'B',_'M',_'Q'),
#  ('A', 'B', 'M', 'R'): table_('A',_'B',_'M',_'R'),
#  ('A', 'B', 'N', 'O'): table_('A',_'B',_'N',_'O'),
#  ('A', 'B', 'N', 'P'): table_('A',_'B',_'N',_'P'),
#  ('A', 'B', 'N', 'Q'): table_('A',_'B',_'N',_'Q'),
#  ('A', 'B', 'N', 'R'): table_('A',_'B',_'N',_'R'),
#  ('A', 'B', 'O', 'P'): table_('A',_'B',_'O',_'P'),
#  ('A', 'B', 'O', 'Q'): table_('A',_'B',_'O',_'Q'),
#  ('A', 'B', 'O', 'R'): table_('A',_'B',_'O',_'R'),
#  ('A', 'B', 'P', 'Q'): table_('A',_'B',_'P',_'Q'),
#  ('A', 'B', 'P', 'R'): table_('A',_'B',_'P',_'R'),
#  ('A', 'B', 'Q', 'R'): table_('A',_'B',_'Q',_'R'),
#  ('A', 'C', 'D', 'E'): table_('A',_'C',_'D',_'E'),
#  ('A', 'C', 'D', 'F'): table_('A',_'C',_'D',_'F'),
#  ('A', 'C', 'D', 'G'): table_('A',_'C',_'D',_'G'),
#  ('A', 'C', 'D', 'I'): table_('A',_'C',_'D',_'I'),
#  ('A', 'C', 'D', 'J'): table_('A',_'C',_'D',_'J'),
#  ('A', 'C', 'D', 'K'): table_('A',_'C',_'D',_'K'),
#  ('A', 'C', 'D', 'L'): table_('A',_'C',_'D',_'L'),
#  ('A', 'C', 'D', 'M'): table_('A',_'C',_'D',_'M'),
#  ('A', 'C', 'D', 'N'): table_('A',_'C',_'D',_'N'),
#  ('A', 'C', 'D', 'O'): table_('A',_'C',_'D',_'O'),
#  ('A', 'C', 'D', 'P'): table_('A',_'C',_'D',_'P'),
#  ('A', 'C', 'D', 'Q'): table_('A',_'C',_'D',_'Q'),
#  ('A', 'C', 'D', 'R'): table_('A',_'C',_'D',_'R'),
#  ('A', 'C', 'E', 'F'): table_('A',_'C',_'E',_'F'),
#  ('A', 'C', 'E', 'G'): table_('A',_'C',_'E',_'G'),
#  ('A', 'C', 'E', 'I'): table_('A',_'C',_'E',_'I'),
#  ('A', 'C', 'E', 'J'): table_('A',_'C',_'E',_'J'),
#  ('A', 'C', 'E', 'K'): table_('A',_'C',_'E',_'K'),
#  ('A', 'C', 'E', 'L'): table_('A',_'C',_'E',_'L'),
#  ('A', 'C', 'E', 'M'): table_('A',_'C',_'E',_'M'),
#  ('A', 'C', 'E', 'N'): table_('A',_'C',_'E',_'N'),
#  ('A', 'C', 'E', 'O'): table_('A',_'C',_'E',_'O'),
#  ('A', 'C', 'E', 'P'): table_('A',_'C',_'E',_'P'),
#  ('A', 'C', 'E', 'Q'): table_('A',_'C',_'E',_'Q'),
#  ('A', 'C', 'E', 'R'): table_('A',_'C',_'E',_'R'),
#  ('A', 'C', 'F', 'G'): table_('A',_'C',_'F',_'G'),
#  ('A', 'C', 'F', 'I'): table_('A',_'C',_'F',_'I'),
#  ('A', 'C', 'F', 'J'): table_('A',_'C',_'F',_'J'),
#  ('A', 'C', 'F', 'K'): table_('A',_'C',_'F',_'K'),
#  ('A', 'C', 'F', 'L'): table_('A',_'C',_'F',_'L'),
#  ('A', 'C', 'F', 'M'): table_('A',_'C',_'F',_'M'),
#  ('A', 'C', 'F', 'N'): table_('A',_'C',_'F',_'N'),
#  ('A', 'C', 'F', 'O'): table_('A',_'C',_'F',_'O'),
#  ('A', 'C', 'F', 'P'): table_('A',_'C',_'F',_'P'),
#  ('A', 'C', 'F', 'Q'): table_('A',_'C',_'F',_'Q'),
#  ('A', 'C', 'F', 'R'): table_('A',_'C',_'F',_'R'),
#  ('A', 'C', 'G', 'I'): table_('A',_'C',_'G',_'I'),
#  ('A', 'C', 'G', 'J'): table_('A',_'C',_'G',_'J'),
#  ('A', 'C', 'G', 'K'): table_('A',_'C',_'G',_'K'),
#  ('A', 'C', 'G', 'L'): table_('A',_'C',_'G',_'L'),
#  ('A', 'C', 'G', 'M'): table_('A',_'C',_'G',_'M'),
#  ('A', 'C', 'G', 'N'): table_('A',_'C',_'G',_'N'),
#  ('A', 'C', 'G', 'O'): table_('A',_'C',_'G',_'O'),
#  ('A', 'C', 'G', 'P'): table_('A',_'C',_'G',_'P'),
#  ('A', 'C', 'G', 'Q'): table_('A',_'C',_'G',_'Q'),
#  ('A', 'C', 'G', 'R'): table_('A',_'C',_'G',_'R'),
#  ('A', 'C', 'I', 'J'): table_('A',_'C',_'I',_'J'),
#  ('A', 'C', 'I', 'K'): table_('A',_'C',_'I',_'K'),
#  ('A', 'C', 'I', 'L'): table_('A',_'C',_'I',_'L'),
#  ('A', 'C', 'I', 'M'): table_('A',_'C',_'I',_'M'),
#  ('A', 'C', 'I', 'N'): table_('A',_'C',_'I',_'N'),
#  ('A', 'C', 'I', 'O'): table_('A',_'C',_'I',_'O'),
#  ('A', 'C', 'I', 'P'): table_('A',_'C',_'I',_'P'),
#  ('A', 'C', 'I', 'Q'): table_('A',_'C',_'I',_'Q'),
#  ('A', 'C', 'I', 'R'): table_('A',_'C',_'I',_'R'),
#  ('A', 'C', 'J', 'K'): table_('A',_'C',_'J',_'K'),
#  ('A', 'C', 'J', 'L'): table_('A',_'C',_'J',_'L'),
#  ('A', 'C', 'J', 'M'): table_('A',_'C',_'J',_'M'),
#  ('A', 'C', 'J', 'N'): table_('A',_'C',_'J',_'N'),
#  ('A', 'C', 'J', 'O'): table_('A',_'C',_'J',_'O'),
#  ('A', 'C', 'J', 'P'): table_('A',_'C',_'J',_'P'),
#  ('A', 'C', 'J', 'Q'): table_('A',_'C',_'J',_'Q'),
#  ...}

# %%
seating_model = pulp.LpProblem("Wedding Seating Model", pulp.LpMinimize)

# %%
seating_model += sum([happiness(table) * x[table] for table in possible_tables])

# %%
#specify the maximum number of tables
seating_model += sum([x[table] for table in possible_tables]) <= max_tables, \
                            "Maximum_number_of_tables"

# %%
#A guest must seated at one and only one table
for guest in guests:
    seating_model += sum([x[table] for table in possible_tables
                                if guest in table]) == 1, "Must_seat_%s"%guest

# %%
seating_model.solve()

print("The choosen tables are out of a total of %s:"%len(possible_tables))
for table in possible_tables:
    if x[table].value() == 1.0:
        print(table)
# Out:
# The choosen tables are out of a total of 3213:
# ('M', 'N')
# ('E', 'F', 'G')
# ('A', 'B', 'C', 'D')
# ('I', 'J', 'K', 'L')
# ('O', 'P', 'Q', 'R')
